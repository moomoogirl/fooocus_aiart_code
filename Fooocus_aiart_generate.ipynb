# %% [markdown]
# <a href="https://colab.research.google.com/github/moomoogirl/fooocus_aiart_code/blob/main/Fooocus_aiart_generate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 🔧 必要ライブラリのインストール
# !pip install -q pygit2==1.12.2
# !sudo apt-get -q install aria2

# 📁 Fooocusをクローン
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git

# ✅ モデル（Checkpoint）をDL（例: Realistic Vision系NSFWモデル）
# !aria2c -x5 https://civitai.com/api/download/models/277445 -d /content/Fooocus/models/checkpoints

# ✅ LoRAをDL（例: セクシー美女補強系）
# !aria2c -x5 https://civitai.com/api/download/models/331598 -d /content/Fooocus/models/loras

# 📦 ダウンロード後、ファイル名を整理
import os

# モデルとLoRAのフォルダパス
ckpt_dir = "/content/Fooocus/models/checkpoints"
lora_dir = "/content/Fooocus/models/loras"

# Checkpointを適切な名前に変更
for file in os.listdir(ckpt_dir):
    if not file.endswith(".safetensors"):
        os.rename(os.path.join(ckpt_dir, file), os.path.join(ckpt_dir, "realisticVision.safetensors"))

# LoRAも適切な名前に変更
for file in os.listdir(lora_dir):
    if not file.endswith(".safetensors"):
        os.rename(os.path.join(lora_dir, file), os.path.join(lora_dir, "sexyLora.safetensors"))

# ▶️ Fooocusを起動（Gradio共有付き、animeプリセット、暗色テーマ）
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram --preset anime --theme dark
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 42.9 MB/s eta 0:00:00
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   libaria2-0 libc-ares2
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2
# 0 upgraded, 3 newly installed, 0 to remove and 34 not upgraded.
# Need to get 1,513 kB of archives.
# After this operation, 5,441 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libc-ares2 amd64 1.18.1-1ubuntu0.22.04.3 [45.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libaria2-0 amd64 1.36.0-1 [1,086 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 aria2 amd64 1.36.0-1 [381 kB]
# Fetched 1,513 kB in 2s (607 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 3.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 126102 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.18.1-1ubuntu0.22.04.3_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.36.0-1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.36.0-1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.36.0-1_amd64.deb ...
# Unpacking aria2 (1.36.0-1) ...
# Setting up libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Setting up libaria2-0:amd64 (1.36.0-1) ...
# Setting up aria2 (1.36.0-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6725, done.
# remote: Total 6725 (delta 0), reused 0 (delta 0), pack-reused 6725 (from 1)
# Receiving objects: 100% (6725/6725), 33.33 MiB | 16.37 MiB/s, done.
# Resolving deltas: 100% (3855/3855), done.
#
# 05/17 09:47:53 [NOTICE] Downloading 1 item(s)
#
# 05/17 09:47:54 [NOTICE] CUID#7 - Redirecting to https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/255714/BlazingrealdriveV03j.fcjq.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22blazingrealdrive_V03j.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250517/us-east-1/s3/aws4_request&X-Amz-Date=20250517T094753Z&X-Amz-SignedHeaders=host&X-Amz-Signature=a6484ea138bee938525d1ee34c13461f22eaa0526323c970a26a8aa0f8724fa1
#
# 05/17 09:47:54 [NOTICE] CUID#9 - Redirecting to https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/255714/BlazingrealdriveV03j.fcjq.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22blazingrealdrive_V03j.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250517/us-east-1/s3/aws4_request&X-Amz-Date=20250517T094754Z&X-Amz-SignedHeaders=host&X-Amz-Signature=3f960c045c805bced38b57fa7fe95c9f1d1a30855e7103b17f5b5fcf0006d9bb
#
# 05/17 09:47:54 [NOTICE] CUID#11 - Redirecting to https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/255714/BlazingrealdriveV03j.fcjq.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22blazingrealdrive_V03j.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250517/us-east-1/s3/aws4_request&X-Amz-Date=20250517T094754Z&X-Amz-SignedHeaders=host&X-Amz-Signature=3f960c045c805bced38b57fa7fe95c9f1d1a30855e7103b17f5b5fcf0006d9bb
#
# 05/17 09:47:54 [NOTICE] CUID#10 - Redirecting to https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/255714/BlazingrealdriveV03j.fcjq.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22blazingrealdrive_V03j.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250517/us-east-1/s3/aws4_request&X-Amz-Date=20250517T094754Z&X-Amz-SignedHeaders=host&X-Amz-Signature=3f960c045c805bced38b57fa7fe95c9f1d1a30855e7103b17f5b5fcf0006d9bb
#
# 05/17 09:47:54 [NOTICE] CUID#12 - Redirecting to https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/255714/BlazingrealdriveV03j.fcjq.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22blazingrealdrive_V03j.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250517/us-east-1/s3/aws4_request&X-Amz-Date=20250517T094754Z&X-Amz-SignedHeaders=host&X-Amz-Signature=3f960c045c805bced38b57fa7fe95c9f1d1a30855e7103b17f5b5fcf0006d9bb
#
# 05/17 09:48:06 [NOTICE] Download complete: /content/Fooocus/models/checkpoints/blazingrealdrive_V03j.safetensors
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# df9812|OK  |   168MiB/s|/content/Fooocus/models/checkpoints/blazingrealdrive_V03j.safetensors
#
# Status Legend:
# (OK):download completed.
#
# 05/17 09:48:06 [NOTICE] Downloading 1 item(s)
#
# 05/17 09:48:07 [NOTICE] CUID#7 - Redirecting to https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/3553185/aestheticAnimeV1s.THVo.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22aesthetic_anime_v1s.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250517/us-east-1/s3/aws4_request&X-Amz-Date=20250517T094807Z&X-Amz-SignedHeaders=host&X-Amz-Signature=180eaaf9ca7644e1656cd6be5f36ac138161c446ad0bde0c34e5042b28670399
#
# 05/17 09:48:07 [NOTICE] CUID#12 - Redirecting to https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/3553185/aestheticAnimeV1s.THVo.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22aesthetic_anime_v1s.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250517/us-east-1/s3/aws4_request&X-Amz-Date=20250517T094807Z&X-Amz-SignedHeaders=host&X-Amz-Signature=180eaaf9ca7644e1656cd6be5f36ac138161c446ad0bde0c34e5042b28670399
#
# 05/17 09:48:07 [NOTICE] CUID#9 - Redirecting to https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/3553185/aestheticAnimeV1s.THVo.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22aesthetic_anime_v1s.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250517/us-east-1/s3/aws4_request&X-Amz-Date=20250517T094807Z&X-Amz-SignedHeaders=host&X-Amz-Signature=180eaaf9ca7644e1656cd6be5f36ac138161c446ad0bde0c34e5042b28670399
#
# 05/17 09:48:08 [NOTICE] CUID#10 - Redirecting to https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/3553185/aestheticAnimeV1s.THVo.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22aesthetic_anime_v1s.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250517/us-east-1/s3/aws4_request&X-Amz-Date=20250517T094808Z&X-Amz-SignedHeaders=host&X-Amz-Signature=fcc8b3ed207678488aabdafe315f2500fdb61824fe6c0047efe369524acb0cf9
#
# 05/17 09:48:08 [NOTICE] CUID#11 - Redirecting to https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/3553185/aestheticAnimeV1s.THVo.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22aesthetic_anime_v1s.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250517/us-east-1/s3/aws4_request&X-Amz-Date=20250517T094808Z&X-Amz-SignedHeaders=host&X-Amz-Signature=fcc8b3ed207678488aabdafe315f2500fdb61824fe6c0047efe369524acb0cf9
#
# 05/17 09:48:10 [NOTICE] Download complete: /content/Fooocus/models/loras/aesthetic_anime_v1s.safetensors
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 3b6591|OK  |   191MiB/s|/content/Fooocus/models/loras/aesthetic_anime_v1s.safetensors
#
# Status Legend:
# (OK):download completed.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram', '--preset', 'anime', '--theme', 'dark']
# Python 3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# Loaded preset: /content/Fooocus/presets/anime.json
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xlvaeapp.pth" to /content/Fooocus/models/vae_approx/xlvaeapp.pth
#
# 100% 209k/209k [00:00<00:00, 69.4MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/vaeapp_sd15.pt" to /content/Fooocus/models/vae_approx/vaeapp_sd15.pth
#
# 100% 209k/209k [00:00<00:00, 44.9MB/s]
# Downloading: "https://huggingface.co/mashb1t/misc/resolve/main/xl-to-v1_interposer-v4.0.safetensors" to /content/Fooocus/models/vae_approx/xl-to-v1_interposer-v4.0.safetensors
#
# 100% 5.40M/5.40M [00:00<00:00, 228MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/fooocus_expansion.bin" to /content/Fooocus/models/prompt_expansion/fooocus_expansion/pytorch_model.bin
#
# 100% 335M/335M [00:00<00:00, 365MB/s]
# Downloading: "https://huggingface.co/mashb1t/fav_models/resolve/main/fav/animaPencilXL_v500.safetensors" to /content/Fooocus/models/checkpoints/animaPencilXL_v500.safetensors
#
# 100% 6.46G/6.46G [00:36<00:00, 192MB/s]
# Total VRAM 15095 MB, total RAM 12978 MB
# Set vram state to: HIGH_VRAM
# Always offload VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using pytorch cross attention
# Refiner unloaded.
# Running on local URL:  http://127.0.0.1:7865
# IMPORTANT: You are using gradio version 3.41.2, however version 4.44.1 is available, please upgrade.
# --------
# model_type EPS
# UNet ADM Dimension 2816
# Running on public URL: https://4ef5464e4fca2a1e87.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# Using pytorch attention in VAE
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# Using pytorch attention in VAE
# extra {'cond_stage_model.clip_l.text_projection', 'cond_stage_model.clip_l.logit_scale'}
# left over keys: dict_keys(['cond_stage_model.clip_l.transformer.text_model.embeddings.position_ids'])
# loaded straight to GPU
# Requested to load SDXL
# Loading 1 new model
# Base model loaded: /content/Fooocus/models/checkpoints/animaPencilXL_v500.safetensors
# VAE loaded: None
# Request to load LoRAs [] for model [/content/Fooocus/models/checkpoints/animaPencilXL_v500.safetensors].
# Fooocus V2 Expansion: Vocab with 642 words.
# Fooocus Expansion engine loaded for cuda:0, use_fp16 = True.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.60 seconds
# 2025-05-17 09:52:38.678202: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747475558.911067    1998 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747475558.973370    1998 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-17 09:52:39.460599: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Started worker with PID 991
# App started successful. Use the app with http://127.0.0.1:7865/ or 127.0.0.1:7865 or https://4ef5464e4fca2a1e87.gradio.live
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 585133882079361940
# [Parameters] CFG = 7.23
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 30
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] 1girl, solo, thick thighs, tanned skin, gal, hand between legs, blonde hair, short hair, wet skin, shiny micro bikini, ((nipple)), embarrassing, cute face, beautiful beach side, shiny bikini, American flag micro bikini, (((enormous breasts))), ((saggy breasts)), ((gigantic boobs)), cinematic angle, (steam), wet skin, hand on the head, Arms up, steam, intricate, elegant, highly detailed, sincere, dramatic light, sharp focus, illuminated ambient professional, stunning, excellent composition, dynamic, creative, positive, thoughtful, awesome, glowing, attractive, elite, best, bright, surreal, perfect, pretty, cheerful, marvelous, brilliant, breathtaking, very
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] 1girl, solo, thick thighs, tanned skin, gal, hand between legs, blonde hair, short hair, wet skin, shiny micro bikini, ((nipple)), embarrassing, cute face, beautiful beach side, shiny bikini, American flag micro bikini, (((enormous breasts))), ((saggy breasts)), ((gigantic boobs)), cinematic angle, (steam), wet skin, hand on the head, Arms up, steam, epic, highly detailed, sharp focus, candid, intricate, elegant, creative, surreal, sublime, glowing, extremely stylish, futuristic, thought original, fine classic, fantastic, inspired, gorgeous, amazing,, artistic, winning, inspirational, perfect, incredible detail, very complimentary colors, vibrant
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.14 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1152, 896)
# Preparation time: 3.64 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.60 seconds
# 100% 60/60 [00:56<00:00,  1.06it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.15 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-05-17/log.html
# Generating and saving time: 60.97 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.17 seconds
# 100% 60/60 [00:55<00:00,  1.07it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.14 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-05-17/log.html
# Generating and saving time: 58.60 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 119.57 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 123.29 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.85 seconds
# Enter Hyper-SD mode.
# [Fooocus] Downloading Hyper-SD components ...
# Downloading: "https://huggingface.co/mashb1t/misc/resolve/main/sdxl_hyper_sd_4step_lora.safetensors" to /content/Fooocus/models/loras/sdxl_hyper_sd_4step_lora.safetensors
#
# 100% 751M/751M [00:06<00:00, 125MB/s]
# [Parameters] Adaptive CFG = 1.0
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] Seed = 5513293412635222598
# [Parameters] CFG = 1.0
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_sde_gpu - karras
# [Parameters] Steps = 4 - 4
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Request to load LoRAs [('sdxl_hyper_sd_4step_lora.safetensors', 0.8)] for model [/content/Fooocus/models/checkpoints/animaPencilXL_v500.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/sdxl_hyper_sd_4step_lora.safetensors] for UNet [/content/Fooocus/models/checkpoints/animaPencilXL_v500.safetensors] with 788 keys at weight 0.8.
# Requested to load SDXLClipModel
# Loading 1 new model
# unload clone 1
# [Fooocus Model Management] Moving model(s) has taken 1.27 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] 1girl, solo, thick thighs, tanned skin, gal, hand between legs, blonde hair, short hair, wet skin, shiny micro bikini, ((nipple)), embarrassing, cute face, beautiful beach side, shiny bikini, American flag micro bikini, (((enormous breasts))), ((saggy breasts)), ((gigantic boobs)), cinematic angle, (steam), wet skin, hand on the head, Arms up, steam, epic, highly detailed, fine detail, intricate, elegant, dynamic, rich deep colors, ambient background, sharp focus, advanced, professional, creative, positive, relaxed, loving, fabulous, unique, attractive, confident, calm, glowing, friendly, pretty, color, light, saturated, surreal
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] 1girl, solo, thick thighs, tanned skin, gal, hand between legs, blonde hair, short hair, wet skin, shiny micro bikini, ((nipple)), embarrassing, cute face, beautiful beach side, shiny bikini, American flag micro bikini, (((enormous breasts))), ((saggy breasts)), ((gigantic boobs)), cinematic angle, (steam), wet skin, hand on the head, Arms up, steam, epic composition, intricate, elegant, highly detailed, dramatic light, sharp focus, ambient background, illuminated, rich deep colors, creative, perfect dynamic,, vibrant, full detail, attractive, very inspirational, stunning, magical, surreal, intriguing, novel, modern, romantic, inspiring, thought
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.14 seconds
# [Fooocus] Encoding positive #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1152, 896)
# Preparation time: 10.27 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.31 seconds
# 100% 4/4 [00:03<00:00,  1.30it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-05-17/log.html
# Generating and saving time: 7.16 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.74 seconds
# 100% 4/4 [00:03<00:00,  1.28it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.32 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-05-17/log.html
# Generating and saving time: 6.67 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 13.83 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 24.14 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.77 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 2735937426999596726
# [Parameters] CFG = 7.23
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 30
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Request to load LoRAs [] for model [/content/Fooocus/models/checkpoints/animaPencilXL_v500.safetensors].
# Requested to load SDXLClipModel
# Loading 1 new model
# unload clone 1
# [Fooocus Model Management] Moving model(s) has taken 1.17 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] 1girl, solo, thick thighs, tanned skin, gal, hand between legs, blonde hair, short hair, wet skin, shiny micro bikini, ((nipple)), embarrassing, cute face, beautiful beach side, shiny bikini, American flag micro bikini, (((enormous breasts))), ((saggy breasts)), ((gigantic boobs)), cinematic angle, (steam), wet skin, hand on the head, Arms up, steam, epic, highly detailed, extremely lush background, fine detail, intricate, elegant, dynamic, illuminated colors, polished, glossy, light, crisp, sharp focus, modern, sublime, appealing, very coherent, ambient, artistic, romantic, mythical, magical, vibrant, color rich deep vivid, focused
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] 1girl